# %%
import model as m
import sys

Model = m.Model()
Model.LoadedCap()

Model.structure.Variables['workingDir']   = "../data/EasterTime/Debug/"
Model.structure.Variables['roundTrips'] = 0
Model.structure.Variables['WallThick'] = 5.0
print("Standard run")
Model.RunTRspectrum()
# Out:
# /home/chriscrossing/anaconda3/envs/mp/lib/python3.10/site-packages/numpy/core/getlimits.py:499: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/chriscrossing/anaconda3/envs/mp/lib/python3.10/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
# ...
# Standard run
#      block, center = (0,0,0)
#           size (1e+20,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.0736,2.0736,2.0736)
# ...
# Normalisation Run
#
#
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000193119 s
# Working in 2D dimensions.
# Computational cell is 70.1 x 11.8 x 0 with resolution 10
#      block, center = (0,0,0)
#           size (1e+20,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
# ...

# %%
import meep as mp
import numpy as np
import matplotlib.pyplot as plt

# %%
#wavelengths
print(1/np.flip(Model.detectors['WGM'].args[0]))


#position
cen = Model.structure.detectors['WGM'].center
#size
size = Model.structure.detectors['WGM'].size
#dimentions
(x,y,z,w) = Model.sim.get_array_metadata(center=cen, size=size)
print(y)

#refractiveindex 
n = np.sqrt(Model.sim.get_array(component=mp.Dielectric,center=cen,size=size))
print(n)
# Out:
# [1.5220414  1.52204239 1.52204338 ... 1.53804025 1.53804126 1.53804227]
# [21.45 21.55 21.65 21.75 21.85 21.95 22.05 22.15 22.25 22.35 22.45 22.55
#  22.65 22.75 22.85 22.95 23.05 23.15 23.25 23.35 23.45 23.55 23.65 23.75
#  23.85 23.95 24.05 24.15 24.25 24.35 24.45 24.55 24.65 24.75 24.85 24.95
#  25.05 25.15 25.25 25.35 25.45 25.55 25.65 25.75 25.85 25.95 26.05 26.15
#  26.25 26.35 26.45 26.55 26.65 26.75 26.85 26.95 27.05 27.15 27.25 27.35
#  27.45 27.55 27.65 27.75 27.85 27.95 28.05 28.15 28.25 28.35 28.45 28.55
#  28.65 28.75 28.85 28.95 29.05 29.15 29.25 29.35 29.45 29.55 29.65 29.75
#  29.85 29.95 30.05 30.15 30.25 30.35 30.45 30.55 30.65 30.75 30.85 30.95
#  31.05 31.15 31.25 31.35 31.45 31.55]
# [2.5        2.5        2.5        2.5        2.5        2.5
#  2.5        2.5        2.5        2.5        2.5        2.5
#  2.5        2.5        2.5        2.5        2.5        2.5
#  2.5        2.5        2.5        2.5        2.5        2.5
# ...
