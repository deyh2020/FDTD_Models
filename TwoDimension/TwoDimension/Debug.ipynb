# %%
import model as m
import sys

Model = m.Model()
Model.LoadedCap()

Model.structure.Variables['workingDir']   = "../data/EasterTime/Debug/"
Model.structure.Variables['roundTrips'] = 1
Model.structure.Variables['WallThick'] = 5.0
print("Standard run")
Model.RunTRspectrum()
# Out:
# ...
# Standard run
#      block, center = (0,0,0)
#           size (1e+20,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.0736,2.0736,2.0736)
# ...
# Normalisation Run
#
#
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000188828 s
# Working in 2D dimensions.
# Computational cell is 70.1 x 11.8 x 0 with resolution 10
#      block, center = (0,0,0)
#           size (1e+20,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.0736,2.0736,2.0736)
# time for set_epsilon = 0.114524 s
# -----------
# MPB solved for frequency_1(0.4,0,0) = 0.325672 after 11 iters
# MPB solved for frequency_1(0.863063,0,0) = 0.644042 after 9 iters
# MPB solved for frequency_1(0.877099,0,0) = 0.653594 after 7 iters
# MPB solved for frequency_1(0.877099,0,0) = 0.653595 after 1 iters
# Meep: using output directory '../data/EasterTime/Debug/'
# ...

# %%
import meep as mp
import numpy as np
import matplotlib.pyplot as plt

# %%
matrix = np.zeros([len(Model.sim.get_dft_array(Model.detectors['WGM'],mp.Ez,0)),Model.Variables['nfreq']],dtype=np.complex128)

for i in range(0,Model.Variables['nfreq']):
    matrix[:,i] = Model.sim.get_dft_array(Model.detectors['WGM'],mp.Ez,i)

# %%
plt.figure(figsize=(16,10))
plt.imshow(np.abs(matrix),aspect=100)
plt.show()
